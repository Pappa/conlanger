# %%
import pandas as pd
from IPython.display import display

from conlanger.tools.inventory_error_clusters import (
    cluster_errors_dataframe,
    filter_errors_by_failure_class,
)

error_log_path = "../.scratch/cleaned-rule-index/inventory/asca-rule-inventory-error.csv"
error_log = pd.read_csv(error_log_path)

error_log.head()
# Out:
#   section_index                         section_name            rule_id  \
# 0       6.1.2.1                 South Omotic to Aari         Aari-x1,x2
# 1     6.2.1.1.4               Proto-Agaw to Xamtanga         Xamtanga-k
# 2     6.2.2.1.2  Proto-Boreafrasian to Egypto-Berber  Egypto-Berber-CVʕ
# 3     6.2.2.1.2  Proto-Boreafrasian to Egypto-Berber  Egypto-Berber-r_2
# 4     6.2.2.1.3           Ancient Egyptian to Coptic           Coptic-r
#
#    alt_idx                                source     ok  \
# 0      NaN  index_diachronica_original.html:1149  False
# 1      0.0  index_diachronica_original.html:1221  False
# 2      NaN  index_diachronica_original.html:1266  False
# 3      NaN  index_diachronica_original.html:1286  False
# 4      NaN  index_diachronica_original.html:1300  False
#
#             failure_class                reason error_token suggested  \
# 0         nested_brackets  asca-unrepresentable         NaN       NaN
# 1             panic_other         broken-syntax         NaN       NaN
# 2         expected_number  asca-unrepresentable         NaN       NaN
# 3         expected_number  asca-unrepresentable         NaN       NaN
# 4  stuff_after_word_bound  asca-unrepresentable         NaN       NaN
#
#   expected                                        description
# 0      NaN  Syntax Error: Cannot have nested brackets of t...
# 1      NaN  thread panicked at src/rule/subrule/substituti...
# 2   number  Syntax Error: Expected number, but received ɡ ...
# 3   number  Syntax Error: Expected number, but received { ...
# 4      NaN  Syntax Error: Cannot have segments after the e...

# %%
unknown_features = filter_errors_by_failure_class(error_log, "unknown_feature")
unknown_groupings = filter_errors_by_failure_class(error_log, "unknown_grouping")
unknown_characters = filter_errors_by_failure_class(error_log, "unknown_character")
expected_underscores = filter_errors_by_failure_class(error_log, "expected_underscore")

# %%
feature_errors = cluster_errors_dataframe(error_log, "unknown_feature")
display(feature_errors.head(3))
# Out:
#   section_index                        rule_id error_token  \
# 0          7.11         Munsee-Delaware-ə+weak        weak
# 1          7.11       Munsee-Delaware-ə+weak_2        weak
# 2          7.11  Munsee-Delaware-a+weak-ə+weak        weak
#
#                                                 rule
# 0        ə[+weak] > ∅ / #_C | ^^^^^ @ Rule 1, Line 1
# 1  ə[+weak] > ∅ / _C[+voice] | ^^^^^ @ Rule 1, Li...
# 2  a[+weak] ə[+weak] > ə / a_[+cont][+voice] | ^^...

# %%
grouping_errors = cluster_errors_dataframe(error_log, "unknown_grouping")
display(grouping_errors.head(3))
# Out:
#   section_index                             rule_id error_token  \
# 0        14.3.1                Colloquial-Tamil-∅_2           M
# 1        17.5.1  Old-Irish-p-t-k-kʷ-b-d-ɡ-m-n-l-r-s           M
# 2      17.7.2.3                   Standard-German-∅           M
#
#                                                 rule
# 0  ∅ > ʉ / {l,ɭ}_# if {M,V:[+long]} previously in...
# 1  p t k kʷ b d ɡ m n l r s > f θ x xʷ v ð ɣ M N ...
# 2                  ∅ > ə / M_r$ | ^ @ Rule 1, Line 1

# %%
character_errors = cluster_errors_dataframe(error_log, "unknown_character")
display(character_errors.head(3))
# Out:
#   section_index                     rule_id error_token  \
# 0     6.2.2.1.8  Coastal-Hadhrami-Arabic-aː           ‘
# 1     6.2.2.1.9    Wādı̄-Hadhrami-Arabic-aː           ‘
# 2    6.2.2.1.18       Biblical-Hebrew-—-a_4           _
#
#                                                 rule
# 0  a:[+long] > e:[+long] / Form VI (tafa:[+long]‘...
# 1  a:[+long] > e:[+long] / Form VI (tafa:[+long]‘...
# 2                   a > _$$$(…) | ^ @ Rule 1, Line 1

# %%
underscore_errors = cluster_errors_dataframe(error_log, "expected_underscore")
display(underscore_errors.head(3))
# Out:
#   section_index                      rule_id error_token  \
# 0    6.2.2.1.18  Biblical-Hebrew-p-b-t-d-k-ɡ          ''
# 1         7.3.2                Gros-Ventre-j           ,
# 2           7.4               Blackfoot-aː_2          ''
#
#                                                 rule
# 0  p b t d k ɡ > b v θ ð x ɣ / non-intial singlet...
# 1               j > ∅ / :{ʃ,θ}: | ^ @ Rule 1, Line 1
# 2          a:[+long] > a / else | ^ @ Rule 1, Line 1
