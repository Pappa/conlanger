# %%
import pandas as pd

error_log_path = "../.scratch/cleaned-rule-index/inventory/asca-rule-inventory-error.csv"

# %%
error_log = pd.read_csv(error_log_path)

error_log.head()
# Out:
#   section_index                                 section_name  \
# 0         6.1.1                 Proto-Omotic to North Omotic
# 1       6.1.1.7                        North Omotic to Yemsa
# 2       6.1.2.1                         South Omotic to Aari
# 3     6.2.1.1.4                       Proto-Agaw to Xamtanga
# 4     6.2.2.1.1  Proto-North Erythrean to Proto-Boreafrasian
#
#                 rule_id  alt_idx                                source     ok  \
# 0     North-Omotic-Vː_2      NaN   index_diachronica_original.html:987  False
# 1              Yemsa-kʼ      NaN  index_diachronica_original.html:1110  False
# 2            Aari-x1,x2      NaN  index_diachronica_original.html:1149  False
# 3            Xamtanga-k      0.0  index_diachronica_original.html:1221  False
# 4  Proto-Boreafrasian-z      NaN  index_diachronica_original.html:1248  False
#
#          failure_class                reason error_token suggested  \
# 0    unknown_character  asca-unrepresentable           +       NaN
# 1  expected_underscore  asca-unrepresentable         NaN       NaN
# 2    unknown_character  asca-unrepresentable           ₁       NaN
# 3          panic_other         broken-syntax         NaN       NaN
# 4  expected_underscore  asca-unrepresentable         NaN       NaN
#
#                                          description
# 0  Syntax Error: Unknown character '+' | V:[+long...
# 1  Syntax Error: Expected '_', but received '' | ...
# 2  Syntax Error: Unknown character '₁' | {x₁,x₂} ...
# 3                                    thread panicked
# 4  Syntax Error: Expected '_', but received '' | ...

# %%
unknown_features = error_log[error_log["failure_class"] == "unknown_feature"]

unknown_features.head()
# Out:
#     section_index                         section_name  \
# 21      6.2.2.1.7  Classical Arabic to Egyptian Arabic
# 84           7.11  Proto-Algonquian to Munsee Delaware
# 85           7.11  Proto-Algonquian to Munsee Delaware
# 86           7.11  Proto-Algonquian to Munsee Delaware
# 101           8.3       Proto-Altaic to Proto-Mongolic
#
#                            rule_id  alt_idx  \
# 21           Egyptian-Arabic-aj-aw      NaN
# 84          Munsee-Delaware-ə+weak      NaN
# 85        Munsee-Delaware-ə+weak_2      NaN
# 86   Munsee-Delaware-a+weak-ə+weak      NaN
# 101            Proto-Mongolic-pʰ_3      NaN
#
#                                    source     ok    failure_class  \
# 21   index_diachronica_original.html:1384  False  unknown_feature
# 84   index_diachronica_original.html:1917  False  unknown_feature
# 85   index_diachronica_original.html:1918  False  unknown_feature
# 86   index_diachronica_original.html:1919  False  unknown_feature
# 101  index_diachronica_original.html:2186  False  unknown_feature
#
#                    reason error_token suggested  \
# 21   asca-unrepresentable      closed      cons
# 84   asca-unrepresentable        weak       man
# 85   asca-unrepresentable        weak       man
# 86   asca-unrepresentable        weak       man
# 101  asca-unrepresentable   highpitch      high
#
#                                            description
# 21   Syntax Error: Unknown feature 'closed'. Did yo...
# 84   Syntax Error: Unknown feature 'weak'. Did you ...
# 85   Syntax Error: Unknown feature 'weak'. Did you ...
# 86   Syntax Error: Unknown feature 'weak'. Did you ...
# 101  Syntax Error: Unknown feature 'highpitch'. Did...

# %%
tone_features = unknown_features[unknown_features["description"].str.contains("tone")]

print(tone_features.shape[0])
unique_tone_features = tone_features['error_token'].unique()

unique_tone_features
# Out:
# 2
# array(['fallingtone'], dtype=object)
